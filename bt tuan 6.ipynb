# %% [markdown]
# ### Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả. Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
lst = list(map(int, input().split()))
z = []
for i in lst:
    if i not in z:
        z.append(i)
print(z)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự

# %%
lst = list(map(int, input().split()))
ketqua = []
tong = 0
for i in lst:
    tong += i
    ketqua.append(tong)

print(ketqua)
# Out:
# [1, 3, 6, 10]

# %% [markdown]
# ### Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp xếp.)

# %%
tup = tuple(map(int, input().split()))
k = int(input())
n = len(tup)

if n > 0:
    k = k % n
    result = tup[k:] + tup[:k]
else:
    result = ()

print(result)
# Out:
# (10,)

# %% [markdown]
# ### Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key đó

# %%
input_data = input().split()
result_dict = {}

for pair in input_data:
    key, value = pair.split(':')
    if key not in result_dict:
        result_dict[key] = []
    result_dict[key].append(value)

print(result_dict)
# Out:
# {'a': ['1', '3'], 'b': ['2']}

# %% [markdown]
# ### Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros':...} (đếm số >0, <0, =0)

# %%
lst = list(map(int, input().split()))

pos = 0
neg = 0
zero = 0

for num in lst:
    if num > 0:
        pos += 1
    elif num < 0:
        neg += 1
    else:
        zero += 1

result = {'positives': pos, 'negatives': neg, 'zeros': zero}
print(result)
# Out:
# {'positives': 3, 'negatives': 0, 'zeros': 0}

# %% [markdown]
# ### Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
numbers = list(map(int, input().split()))
tong = sum(numbers)
print(tong)
# Out:
# 10

# %% [markdown]
# ### Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo ngược

# %%
tup = tuple(map(int, input().split()))

if len(tup) > 0:
    first = tup[0]
    last = tup[-1]
    reversed_tup = tup[::-1]
    
    print(first)
    print(last)
    print(reversed_tup)
# Out:
# 1
# 5
# (5, 4, 3, 2, 1)

# %% [markdown]
# ### Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng chuỗi và lưu vào dictionary

# %%
chu = input().split()
dem_chu = {}

for i in chu:
    if i in dem_chu:
        dem_chu[i] += 1
    else:
        dem_chu[i] = 1

print(dem_chu)
# Out:
# {'1': 2, '2': 2, '3': 1, '4': 1}

# %% [markdown]
# ### Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của key.

# %%
dict1 = eval(input())
dict2 = eval(input())

for key, value in dict2.items():
    if key in dict1:
        dict1[key] += value
    else:
        dict1[key] = value  
sorted_keys = sorted(dict1)
result = {}
for key in sorted_keys:
    result[key] = dict1[key]
print(result)
# Out:
# {'a': 4}

# %% [markdown]
# ### Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
lst = list(map(int, input().split()))
k = int(input())

cap_so = []
n = len(lst)

for i in range(n):
    for j in range(i + 1, n):
        if lst[i] + lst[j] == k:
            if lst[i] != lst[j]:
                cap_so.append((lst[i], lst[j]))
print(cap_so)
# Out:
# [(1, 5), (2, 4)]

# %% [markdown]
# ### [Tách số chẵn và lẻ từ tuple] Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
tup = tuple(map(int, input().split()))

chan = []
le = []

for i in tup:
    if i % 2 == 0:
        chan.append(i)
    else:
        le.append(i)

print(tuple(chan))
print(tuple(le))
# Out:
# (2, 4, 6, 8)
# (1, 3, 5, 7)

# %% [markdown]
# ### [Tìm phần tử xuất hiện nhiều nhất] Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất trong số đó.

# %%
lst = list(map(int, input().split()))
counts = {}
for i in lst:
    if i in counts:
        counts[i] += 1
    else:
        counts[i] = 1
max_freq = -1
result_num = None
for i, freq in counts.items():
    if freq > max_freq:
        max_freq = freq
        result_num = i
    elif freq == max_freq:
        if i < result_num:
            result_num = i
print(result_num)

# %% [markdown]
# ### [Đảo ngược key và value của dictionary] Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In ra dictionary mới.

# %%
n = input().split()
original_dict = {}
for pair in n:
    key, val = pair.split(':')
    original_dict[key] = val
reversed_dict = {val: key for key, val in original_dict.items()}
print(reversed_dict)

# %% [markdown]
# ### [Giao của hai danh sách] Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các phần tử chung đó, không trùng lặp.

# %%
list1 = list(map(int, input().split()))
list2 = list(map(int, input().split()))
giao = []
for i in list1:
    if i in list2 and i not in giao:
        giao.append(i)

print(giao)
# Out:
# [4, 5, 6]

# %% [markdown]
# ### [Lọc dictionary theo giá trị] Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp keyvalue từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
n = input().split()
k = int(input())
original_dict = {}
for pair in n:
    key, val = pair.split(':')
    original_dict[key] = int(val)
new_dict = {key: val for key, val in original_dict.items() if val > k}
print(new_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 n = input().split()
# ----> 2 k = int(input())
#       3 original_dict = {}
#       4 for pair in n:
#
# ValueError: invalid literal for int() with base 10: ''
