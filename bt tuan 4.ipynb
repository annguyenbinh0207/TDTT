# %% [markdown]
# ### Bai 1

# %%
n = int(input())
tong = 0
for i in range(n+1):
    tong += i
print("tong =" ,tong)
# Out:
# tong = 6

# %% [markdown]
# ### Bai 2

# %%
n = -1
while n <= 0:
    n = int(input())
print(n)
# Out:
# 6

# %% [markdown]
# ### Bai 3

# %%
n = int(input())
tich = 1
for i in range(1,n+1):
    tich *= i
print(tich)
# Out:
# 120

# %% [markdown]
# ### Bai 4

# %%
n = int(input())
if n < 0:
    n = -n
count = 0
if n == 0:
    count = 1
else:
    while n > 0:
        n = n // 10
        count = count + 1
print(count)

# %% [markdown]
# ### Bai 5

# %%
n = int(input())
jackpot = 0
for i in range(n):
    so = int(input())
    if so == 42:
        jackpot = jackpot + 1
if jackpot > 0:
    print("I've found the meaning of life!")
else:
    print("It's a joke!")
# Out:
# It's a joke!

# %% [markdown]
# ### Bai 6

# %% [markdown]
# ### Bai 7

# %%
n = int(input())
k = 2
m = 0
while k * k <= n:
    while n % k == 0:
        m = k
        n = n // k
    k = k + 1
if n > 1:
    m = n
print(m)
# Out:
# 2

# %% [markdown]
# ### Bai 8

# %%
n = input()
b = 0
while True:
    r = n[::-1]
    if n == r:
        break
    n = str(int(n) + int(r))
    b = b + 1
print(b, n)
# Out:
# 1 33

# %% [markdown]
# ### Bai 9

# %%
n = int(input())
t = 0
i = 1
while i * i <= n:
    s = i * i
    c = str(s)
    ok = True
    for j in range(10):
        d = 0
        for chu_so in c:
            if chu_so == str(j):
                d = d + 1
        if d > 1:
            ok = False
            break     
    if ok:
        print(s, end=" ")
        t = t + 1
    i = i + 1
if t == 0:
    print("(no number)")
# Out:
# 1 4 9 16 25

# %% [markdown]
# ### Bai 10

# %% [markdown]
# ### Bai 11

# %%
n = int(input())
uoc = 0
if n % 2 == 0:
    for i in range(2, n + 1, 2):
        if n % i == 0:
            uoc += 1
print(uoc)
# Out:
# 3

# %% [markdown]
# ### Bai 12

# %%
x = float(input())
n = int(input())
tong = x*((1 + 0.007)**n)
print(int(tong))
# Out:
# 1087

# %% [markdown]
# ### Bai 13

# %%
a = int(input())
b = int(input())
s1 = 0
for i in range(1, a):
    if a % i == 0:
        s1 = s1 + i
s2 = 0
for i in range(1, b):
    if b % i == 0:
        s2 = s2 + i
if s1 == b and s2 == a:
    print("true")
else:
    print("false")

# %% [markdown]
# ### Bai 14

# %%
import math
m = int(input())
n = int(input())
print(math.gcd(m,n))
# Out:
# 9

# %% [markdown]
# ### Bai 15

# %%
a = int(input())
b = int(input())
if a%2 ==0 and b%4==0:
    x =a - (b-2*a)/2
    y = (b-2*a)/2
    if x > 0 and y > 0:
        print(x , y)
    else:
        print("invalid")
else:
    print("invalid")
# Out:
# 22.0 14.0
